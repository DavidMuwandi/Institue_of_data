# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
# from google.colab import files
# uploaded = files.upload()
# import io
df = pd.read_csv("Employee-attrition_module1.csv")

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# 49649  Customer Service       Cashier          44            F      Female
# 49650  Customer Service       Cashier          39            F      Female
# 49651  Customer Service       Cashier          16            F      Female
# 49652  Customer Service       Cashier          13            F      Female
#
#       termreason_desc termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 49648          Layoff   Involuntary         2015  TERMINATED        STORES
# 49649      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49650          Layoff   Involuntary         2015  TERMINATED        STORES
# 49651      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49652          Layoff   Involuntary         2014  TERMINATED        STORES

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find Shape of Data Frame

# %%
# A:
df.shape
# Out:
# (49653, 18)

# %% [markdown]
# #### 1.B Find Data Tyeps of Data Frame

# %%
# A:
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### 1.C Find Number of Data Types in a Data Frame
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore difference.

# %%
# A:
df.dtypes.
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of Job_Title column

# %%
# A:
df["job_title"]
# Out:
# 0                 CEO
# 1                 CEO
# 2                 CEO
# 3                 CEO
# 4                 CEO
#              ...
# 49648    Dairy Person
# 49649         Cashier
# 49650         Cashier
# 49651         Cashier
# 49652         Cashier
# Name: job_title, Length: 49653, dtype: object

# %% [markdown]
# #### 2.B Find How Many Rows Are in Each Job Title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
# A: 

df['job_title'].value_counts()
# Out:
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Meats Manager                       285
# Bakery Manager                      285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Accounts Receiveable Clerk           30
# Labor Relations Analyst              30
# Trainer                              26
# Accounts Payable Clerk               25
# Investment Analyst                   20
# Compensation Analyst                 20
# Auditor                              20
# Systems Analyst                      20
# Corporate Lawyer                     17
# Exec Assistant, VP Stores            10
# Legal Counsel                        10
# VP Finance                           10
# CHief Information Officer            10
# Exec Assistant, Finance              10
# CEO                                  10
# Exec Assistant, Legal Counsel        10
# Director, Recruitment                10
# VP Stores                            10
# Exec Assistant, Human Resources      10
# VP Human Resources                   10
# Director, Employee Records            9
# Director, HR Technology               9
# Dairy Manager                         9
# Director, Accounts Payable            9
# Director, Accounts Receivable         9
# Director, Accounting                  9
# Director, Training                    4
# Director, Labor Relations             4
# Director, Audit                       4
# Director, Investments                 4
# Director, Compensation                4
# Name: job_title, dtype: int64

# %% [markdown]
# #### 2.C [BONUS] Write A Function to Row Count
#
#
#
# ```
# def row_count(column_name):
#     number_of_rows = 0
#     return number_of_rows
# ```

# %%
def row_count(x):
    count = len(df.x)
    return count

row_count(age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-170-7d51354fd8b1> in <module>
#       3     return count
#       4
# ----> 5 row_count(age)
#       6
#       7
#
# NameError: name 'age' is not defined

# %%
len(df.age)
# Out:
# 49653

# %% [markdown]
# #### 2.D Describe 'Age'
#
# Find count,  mean,  std, min, max of column 'age'

# %%
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ##### 2.E [BONUS] Describe 'All Numeric Columns of Data Frame
#
# Find count, mean, std, min, max of of all columns of dataframe

# %%
# A:

df.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %%
# A:

# %% [markdown]
# # 3. Making The Index Meaningful

# %%
# A:

df.index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %% [markdown]
# #### 3.A Find A Specifc Row Using Index

# %%
# A:

df.iloc[2]
# Out:
# EmployeeID                        1318
# recorddate_key         12/31/2008 0:00
# birthdate_key                 1/3/1954
# orighiredate_key             8/28/1989
# terminationdate_key           1/1/1900
# age                                 54
# length_of_service                   19
# city_name                    Vancouver
# department_name              Executive
# job_title                          CEO
# store_name                          35
# gender_short                         M
# gender_full                       Male
# termreason_desc         Not Applicable
# termtype_desc           Not Applicable
# STATUS_YEAR                       2008
# STATUS                          ACTIVE
# BUSINESS_UNIT               HEADOFFICE
# Name: 2, dtype: object

# %% [markdown]
# #### 3.B Sort Data Frame using Index

# %%
# A:

df.sort_index( ascending = False)
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# ...           ...              ...           ...              ...
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49652          12/30/2014   20                  1  Grand Forks
# 49651          12/31/2013   19                  0      Kelowna
# 49650          12/30/2015   21                  2   White Rock
# 49649           8/30/2013   19                  0    Vancouver
# 49648          12/30/2015   21                  2    Valemount
# ...                   ...  ...                ...          ...
# 4                1/1/1900   56                 21    Vancouver
# 3                1/1/1900   55                 20    Vancouver
# 2                1/1/1900   54                 19    Vancouver
# 1                1/1/1900   53                 18    Vancouver
# 0                1/1/1900   52                 17    Vancouver
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49652  Customer Service       Cashier          13            F      Female
# 49651  Customer Service       Cashier          16            F      Female
# 49650  Customer Service       Cashier          39            F      Female
# 49649  Customer Service       Cashier          44            F      Female
# 49648             Dairy  Dairy Person          34            M        Male
# ...                 ...           ...         ...          ...         ...
# 4             Executive           CEO          35            M        Male
# 3             Executive           CEO          35            M        Male
# 2             Executive           CEO          35            M        Male
# 1             Executive           CEO          35            M        Male
# 0             Executive           CEO          35            M        Male
#
#       termreason_desc   termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 49652          Layoff     Involuntary         2014  TERMINATED        STORES
# 49651      Resignaton       Voluntary         2013  TERMINATED        STORES
# 49650          Layoff     Involuntary         2015  TERMINATED        STORES
# 49649      Resignaton       Voluntary         2013  TERMINATED        STORES
# 49648          Layoff     Involuntary         2015  TERMINATED        STORES
# ...               ...             ...          ...         ...           ...
# 4      Not Applicable  Not Applicable         2010      ACTIVE    HEADOFFICE
# 3      Not Applicable  Not Applicable         2009      ACTIVE    HEADOFFICE
# 2      Not Applicable  Not Applicable         2008      ACTIVE    HEADOFFICE
# 1      Not Applicable  Not Applicable         2007      ACTIVE    HEADOFFICE
# 0      Not Applicable  Not Applicable         2006      ACTIVE    HEADOFFICE
#
# [49653 rows x 18 columns]

# %% [markdown]
# #### 3.C [BONUS] Sort Data Frame using Age

# %%
# A:

df.sort_values(by='age', ascending=True)
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 48132        8325  12/31/2013 0:00     12/7/1994       11/29/2013
# 47925        8253  12/31/2013 0:00     5/15/1994        8/12/2013
# 47922        8252  12/31/2013 0:00     5/10/1994         8/9/2013
# 47919        8251  12/31/2013 0:00      5/7/1994         8/7/2013
# 47916        8250  12/31/2013 0:00     4/26/1994         8/2/2013
# ...           ...              ...           ...              ...
# 48635        3262    8/1/2008 0:00     8/23/1943        2/28/1995
# 48634        3248    8/1/2008 0:00     8/14/1943        2/19/1995
# 49127        4948    7/1/2013 0:00      7/9/1948        1/14/2000
# 48651        3356   11/1/2008 0:00    11/18/1943        5/26/1995
# 48820        4138    2/1/2011 0:00     2/12/1946        8/20/1997
#
#       terminationdate_key  age  length_of_service        city_name  \
# 48132            1/1/1900   19                  0        Cranbrook
# 47925            1/1/1900   19                  0  North Vancouver
# 47922            1/1/1900   19                  0         Victoria
# 47919            1/1/1900   19                  0        Vancouver
# 47916            1/1/1900   19                  0          Burnaby
# ...                   ...  ...                ...              ...
# 48635           8/23/2008   65                 13          Nanaimo
# 48634           8/14/2008   65                 13        Vancouver
# 49127            7/9/2013   65                 13          Burnaby
# 48651          11/18/2008   65                 13          Nanaimo
# 48820           2/12/2011   65                 13           Surrey
#
#         department_name      job_title  store_name gender_short gender_full  \
# 48132  Customer Service        Cashier           8            M        Male
# 47925  Customer Service        Cashier          22            F      Female
# 47922  Customer Service        Cashier          46            F      Female
# 47919  Customer Service        Cashier          44            F      Female
# 47916             Dairy   Dairy Person           5            F      Female
# ...                 ...            ...         ...          ...         ...
# 48635             Meats    Meat Cutter          18            F      Female
# 48634             Dairy   Dairy Person          35            F      Female
# 49127           Produce  Produce Clerk           5            F      Female
# 48651             Meats    Meat Cutter          18            F      Female
# 48820           Produce  Produce Clerk          31            F      Female
#
#       termreason_desc   termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 48132  Not Applicable  Not Applicable         2013      ACTIVE        STORES
# 47925  Not Applicable  Not Applicable         2013      ACTIVE        STORES
# 47922  Not Applicable  Not Applicable         2013      ACTIVE        STORES
# 47919  Not Applicable  Not Applicable         2013      ACTIVE        STORES
# 47916  Not Applicable  Not Applicable         2013      ACTIVE        STORES
# ...               ...             ...          ...         ...           ...
# 48635      Retirement       Voluntary         2008  TERMINATED        STORES
# 48634      Retirement       Voluntary         2008  TERMINATED        STORES
# 49127      Retirement       Voluntary         2013  TERMINATED        STORES
# 48651      Retirement       Voluntary         2008  TERMINATED        STORES
# 48820      Retirement       Voluntary         2011  TERMINATED        STORES
#
# [49653 rows x 18 columns]

# %% [markdown]
# #### 3.D [BONUS] Using Sample Select Any Row

# %%
# A:

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find Rows Where Job_Title is CEO

# %%
# A:

df.loc[df['job_title']== 'CEO']
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
# 5            1/1/1900   57                 22  Vancouver       Executive
# 6            1/1/1900   58                 23  Vancouver       Executive
# 7            1/1/1900   59                 24  Vancouver       Executive
# 8            1/1/1900   60                 25  Vancouver       Executive
# 9            1/1/1900   61                 26  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
# 5       CEO          35            M        Male  Not Applicable
# 6       CEO          35            M        Male  Not Applicable
# 7       CEO          35            M        Male  Not Applicable
# 8       CEO          35            M        Male  Not Applicable
# 9       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE
# 5  Not Applicable         2011  ACTIVE    HEADOFFICE
# 6  Not Applicable         2012  ACTIVE    HEADOFFICE
# 7  Not Applicable         2013  ACTIVE    HEADOFFICE
# 8  Not Applicable         2014  ACTIVE    HEADOFFICE
# 9  Not Applicable         2015  ACTIVE    HEADOFFICE

# %% [markdown]
# #### 4.B Group By Age

# %%
# A:

group_by_age = df.groupby('age')['EmployeeID'].apply(list)

group_by_age_df = pd.DataFrame(group_by_age)

group_by_age_df
# Out:
#                                             EmployeeID
# age
# 19   [8088, 8089, 8090, 8091, 8092, 8093, 8094, 809...
# 20   [7824, 7825, 7826, 7827, 7828, 7829, 7830, 783...
# 21   [7562, 7563, 7564, 7565, 7566, 7567, 7568, 756...
# 22   [7295, 7296, 7297, 7298, 7299, 7300, 7301, 730...
# 23   [7025, 7026, 7027, 7028, 7029, 7030, 7031, 703...
# 24   [6773, 6774, 6775, 6776, 6777, 6778, 6779, 678...
# 25   [6523, 6524, 6525, 6526, 6527, 6528, 6529, 653...
# 26   [6395, 6396, 6397, 6398, 6399, 6400, 6401, 640...
# 27   [6253, 6254, 6255, 6256, 6257, 6258, 6259, 626...
# 28   [6130, 6131, 6132, 6133, 6134, 6135, 6136, 613...
# 29   [6010, 6011, 6012, 6013, 6014, 6015, 6016, 601...
# 30   [5898, 5899, 5900, 5901, 5902, 5903, 5904, 590...
# 31   [5787, 5788, 5789, 5790, 5791, 5792, 5793, 579...
# 32   [5664, 5665, 5666, 5667, 5668, 5669, 5670, 567...
# 33   [5534, 5535, 5536, 5537, 5538, 5539, 5540, 554...
# 34   [5403, 5404, 5405, 5406, 5407, 5408, 5409, 541...
# 35   [5289, 5290, 5291, 5292, 5293, 5294, 5295, 529...
# 36   [5178, 5179, 5180, 5181, 5182, 5183, 5184, 518...
# 37   [5016, 5017, 5019, 5022, 5023, 5024, 5026, 502...
# 38   [4831, 4832, 4834, 4837, 4838, 4839, 4840, 484...
# 39   [1329, 1330, 4663, 4664, 4666, 4667, 4668, 467...
# 40   [1329, 1330, 4492, 4494, 4498, 4499, 4502, 450...
# 41   [1329, 1330, 1331, 4312, 4313, 4314, 4316, 431...
# 42   [1325, 1329, 1330, 1331, 4117, 4119, 4120, 412...
# 43   [1325, 1329, 1330, 1331, 3938, 3940, 3941, 394...
# 44   [1323, 1325, 1329, 1330, 1331, 1335, 3748, 374...
# 45   [1323, 1325, 1329, 1330, 1331, 1334, 1335, 357...
# 46   [1323, 1325, 1329, 1330, 1331, 1334, 1335, 338...
# 47   [1321, 1323, 1325, 1329, 1330, 1331, 1334, 133...
# 48   [1321, 1322, 1323, 1325, 1329, 1330, 1331, 133...
# 49   [1319, 1321, 1322, 1323, 1325, 1331, 1334, 133...
# 50   [1319, 1321, 1322, 1323, 1325, 1328, 1331, 133...
# 51   [1319, 1320, 1321, 1322, 1323, 1325, 1328, 133...
# 52   [1318, 1319, 1320, 1321, 1322, 1323, 1328, 133...
# 53   [1318, 1319, 1320, 1321, 1322, 1323, 1328, 133...
# 54   [1318, 1319, 1320, 1321, 1322, 1328, 1332, 133...
# 55   [1318, 1319, 1320, 1321, 1322, 1328, 1332, 170...
# 56   [1318, 1319, 1320, 1321, 1322, 1328, 1332, 151...
# 57   [1318, 1319, 1320, 1322, 1328, 1332, 1338, 133...
# 58   [1318, 1319, 1320, 1328, 1332, 1338, 1339, 134...
# 59   [1318, 1320, 1328, 1332, 1338, 1339, 1340, 134...
# 60   [1318, 1320, 1332, 1339, 1343, 1344, 1346, 135...
# 61   [1318, 1339, 1343, 1344, 1346, 1352, 1359, 136...
# 62   [1339, 1343, 1344, 1346, 1352, 1359, 1360, 136...
# 63   [1339, 1343, 1344, 1346, 1352, 1359, 1360, 136...
# 64   [1339, 1343, 1344, 1346, 1352, 1359, 1360, 136...
# 65   [3008, 3401, 1339, 1343, 1344, 1346, 1352, 135...

# %%
age_groups = df.groupby('age').size()

age_groups
# Out:
# age
# 19     158
# 20     408
# 21     703
# 22     815
# 23     960
# 24    1111
# 25    1197
# 26    1210
# 27    1235
# 28    1225
# 29    1227
# 30    1212
# 31    1146
# 32    1153
# 33    1164
# 34    1188
# 35    1189
# 36    1176
# 37    1149
# 38    1156
# 39    1142
# 40    1130
# 41    1135
# 42    1152
# 43    1150
# 44    1157
# 45    1141
# 46    1161
# 47    1173
# 48    1180
# 49    1196
# 50    1218
# 51    1207
# 52    1188
# 53    1188
# 54    1159
# 55    1168
# 56    1154
# 57    1130
# 58    1130
# 59    1128
# 60    1109
# 61     757
# 62     712
# 63     667
# 64     646
# 65     593
# dtype: int64

# %% [markdown]
# # 5. Visualization
#
# > Indented block
#
#
#
# #### 5.A Plot Histogram of Age

# %%
import matplotlib.pyplot as plt

x = df[['age']]

plt.hist(x, bins = 26)


plt.ylabel("Count")
plt.title("AGE HISTOGRAM")



plt.show()

# %% [markdown]
# #### 5.B BoxPlot of Age

# %%
# A:

# %% [markdown]
# #### 5.C Scatterplot of age and length_of_service

# %%
# A:

plt.scatter(df[['age']], df[['length_of_service']])
plt.ylabel('Length of service')

plt.title(' Age Vs length of service')

plt.show()

# %% [markdown]
# #### 5.D Plot Histogram of store_name

# %%
# A:


plt.hist(df['store_name'])

plt.ylabel('count')
plt.title(' STORE NAME HISTOGRAM')

plt.show()

# %% [markdown]
# #### 5.E Print Statistical Summary of Age

# %%
# A:
(df[['age']]).describe()
# Out:
#                 age
# count  49653.000000
# mean      42.077035
# std       12.427257
# min       19.000000
# 25%       31.000000
# 50%       42.000000
# 75%       53.000000
# max       65.000000

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
