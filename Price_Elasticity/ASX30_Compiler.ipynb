# %% [markdown]
# ### Compiling a dataset for top 30 ASX Stocks from individual csv files download from y-finance.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('BHP.AX.csv')
df2 = pd.read_csv("CBA.AX.csv")
df3 = pd.read_csv('RIO.AX.csv')
df4 = pd.read_csv('SHL.AX.csv')
df5 = pd.read_csv('SUN.AX.csv')
df6 = pd.read_csv('REA.AX.csv')
df7 = pd.read_csv('RHC.AX.csv')
df8 = pd.read_csv('IAG.AX.csv')
df9 = pd.read_csv('ASX.AX.csv')
df10 = pd.read_csv("STO.AX.csv")
df11 = pd.read_csv('QBE.AX.csv')
df12 = pd.read_csv('SYD.AX.csv')
df13 = pd.read_csv('BXB.AX.csv')
df14 = pd.read_csv('SCG.AX.csv')
df15 = pd.read_csv('NCM.AX.csv')
df16 = pd.read_csv('COL.AX.csv')
df17 = pd.read_csv('ALL.AX.csv')
df18 = pd.read_csv('AMC.AX.csv')
df19 = pd.read_csv("GMG.AX.csv")
df20 = pd.read_csv('WPL.AX.csv')
df21 = pd.read_csv('FMG.AX.csv')
df22 = pd.read_csv('TCL.AX.csv')
df23 = pd.read_csv('TLS.AX.csv')
df24 = pd.read_csv('WES.AX.csv')
df25 = pd.read_csv('MQG.AX.csv')
df26 = pd.read_csv('WOW.AX.csv')
df27 = pd.read_csv("ANZ.AX.csv")
df28 = pd.read_csv('NAB.AX.csv')
df29 = pd.read_csv('WBC.AX.csv')
df30 = pd.read_csv('CSL.AX.csv')

# %%
df_ASX = pd.DataFrame([])

df_ASX = df_ASX.append([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30])

# %%
print(df_ASX)
# Out:
#      Stock      Date        Open        High         Low       Close  \
# 0      BHP  04/01/10   39.947372   40.423939   39.909992   40.255737
# 1      BHP  05/01/10   40.648205   40.779026   40.395905   40.442627
# 2      BHP  06/01/10   40.722958   40.975258   40.685581   40.947224
# 3      BHP  07/01/10   41.031322   41.246246   40.881813   40.900501
# 4      BHP  08/01/10   40.825748   40.993946   40.648205   40.760338
# ...    ...       ...         ...         ...         ...         ...
# 2824   CSL  05/03/21  253.470001  253.710007  246.100006  248.580002
# 2825   CSL  08/03/21  253.149994  253.190002  246.000000  246.000000
# 2826   CSL  09/03/21  245.000000  251.160004  242.000000  250.160004
# 2827   CSL  10/03/21  255.350006  256.609985  252.210007  252.210007
# 2828   CSL  11/03/21  253.880005  255.000000  250.029999  252.139999
#
#        Adj Close     Volume Sock
# 0      24.291389  3949861.0  NaN
# 1      24.404165  9721826.0  NaN
# 2      24.708651  6951354.0  NaN
# ...

# %%
df_ASX.to_csv('ASX30.csv')

# %%
plt.figure(figsize = (50,30))
sns.set_context('paper')
sns.lineplot(x = df_ASX.Date, y = df_ASX.Open, data = df_ASX, hue = 'Stock')

plt.show()
